# %%
import tensorflow as tf
import tensorflow_hub as hub
import pandas as pd
import numpy as np
import os

# %%
os.listdir('data/amazon')
# Out:
# ['unprocessed.tar.gz']

# %%
pd.read_csv('data/opinRank/hotels/data/shanghai/china_shanghai_shanghai_jc_mandarin')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-57-14d7c2f723e0> in <module>
# ----> 1 pd.read_csv('data/opinRank/hotels/data/shanghai/china_shanghai_shanghai_jc_mandarin.csv')
#
# ~/anaconda3/envs/tf2alpha/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
(x_train, y_train), (x_test, y_test)= tf.keras.datasets.reuters.load_data()

# %%
word_index = tf.keras.datasets.reuters.get_word_index

# %%
vocab = len(word_index())

# %%
word_index()
# Out:
# {'mdbl': 10996,
#  'fawc': 16260,
#  'degussa': 12089,
#  'woods': 8803,
#  'hanging': 13796,
#  'localized': 20672,
#  'sation': 20673,
#  'chanthaburi': 20675,
#  'refunding': 10997,
#  'hermann': 8804,
#  'passsengers': 20676,
#  'stipulate': 20677,
#  'heublein': 8352,
#  'screaming': 20713,
#  'tcby': 16261,
#  'four': 185,
#  'grains': 1642,
#  'broiler': 20680,
#  'wooden': 12090,
#  'wednesday': 1220,
#  'highveld': 13797,
#  'duffour': 7593,
#  '0053': 20681,
#  'elections': 3914,
#  '270': 2563,
#  '271': 3551,
#  '272': 5113,
#  '273': 3552,
#  '274': 3400,
#  'rudman': 7975,
#  '276': 3401,
#  '277': 3478,
#  '278': 3632,
#  '279': 4309,
#  'dormancy': 9381,
#  'errors': 7247,
#  'deferred': 3086,
#  'sptnd': 20683,
#  'cooking': 8805,
#  'stratabit': 20684,
#  'designing': 16262,
#  'metalurgicos': 20685,
#  'databank': 13798,
#  '300er': 20686,
#  'shocks': 20687,
#  'nawg': 7972,
#  'tnta': 20688,
#  'perforations': 20689,
#  'affiliates': 2891,
#  '27p': 20690,
# ...

# %%
idx2char = dict(zip(word_index().values(), word_index().keys()))

# %%
[idx2char[o] for o in x_train[0]]
# Out:
# ['the',
#  'wattie',
#  'nondiscriminatory',
#  'mln',
#  'loss',
#  'for',
#  'plc',
#  'said',
#  'at',
#  'only',
#  'ended',
#  'said',
#  'commonwealth',
#  'could',
#  '1',
#  'traders',
#  'now',
#  'april',
#  '0',
#  'a',
#  'after',
#  'said',
#  'from',
#  '1985',
#  'and',
#  'from',
#  'foreign',
#  '000',
#  'april',
#  '0',
#  'prices',
#  'its',
#  'account',
#  'year',
#  'a',
#  'but',
#  'in',
#  'this',
#  'mln',
#  'home',
#  'an',
#  'states',
#  'earlier',
#  'and',
#  'rise',
#  'and',
#  'revs',
#  'vs',
#  '000',
#  'its',
#  '16',
#  'vs',
#  '000',
#  'a',
#  'but',
#  '3',
#  'psbr',
#  'oils',
#  'several',
#  'and',
#  'shareholders',
#  'and',
#  'dividend',
#  'vs',
#  '000',
#  'its',
#  'all',
#  '4',
#  'vs',
#  '000',
#  '1',
#  'mln',
#  'agreed',
#  'largely',
#  'april',
#  '0',
#  'are',
#  '2',
#  'states',
#  'will',
#  'billion',
#  'total',
#  'and',
#  'against',
#  '000',
#  'pct',
#  'dlrs']

# %%
train_input_fn = tf.estimator.inputs.numpy_input_fn(
    x_train, y_train, num_epochs=None, shuffle=True)

predict_train_input_fn = tf.estimator.inputs.numpy_input_fn(
    x_train, y_train, shuffle=False)

predict_test_input_fn = tf.estimator.inputs.numpy_input_fn(
    x_test, y_test, shuffle=False)

# %%
embedded_text_feature_column = hub.text_embedding_column(
    key="sentence", module_spec="https://tfhub.dev/google/nnlm-en-dim128/1")

# %%
tf.keras.optimizers.Adam(learning_rate=0.003)

# %%
estimator = tf.estimator.DNNClassifier(hidden_units=[500,100],
                                      feature_columns=[embedded_text_feature_column],
                                      n_classes=2,
                                      optimizer=tf.keras.optimizers.Adam(learning_rate=0.003))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0409 22:28:11.637310 140341842511680 estimator.py:1760] Using temporary folder as model directory: /tmp/tmpwbcroxh4

# %%
estimator.train(input_fn=train_input_fn, steps=3000)
# Out:
# W0409 22:28:23.340811 140341842511680 deprecation.py:323] From /home/eigenstir/anaconda3/envs/tf2alpha/lib/python3.7/site-packages/tensorflow/python/training/training_util.py:238: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# W0409 22:28:23.349579 140341842511680 deprecation.py:323] From /home/eigenstir/anaconda3/envs/tf2alpha/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# ...
